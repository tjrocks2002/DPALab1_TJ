# %% [markdown]
# # Lab Assignment 1: How to Get Yourself Unstuck
#
# **DS 6001 · 100 points**
#
# ---
#
# ### A note on tools
#
# This lab asks you to use an AI coding assistant. **Use whichever one you like** — Claude, ChatGPT, Copilot, Gemini, Cursor, or whatever has been released since this was written. If you do not have access to any of these, let me know and I will show you one you can use for free. Do not install anything specific for this course. Record which tool and which model you used in the cell below, because your answers will depend on it and we want to compare across the class.
#
# The point of this lab is not that you can get an assistant to produce working code. You can. The point is that you can tell whether what it produced is *correct*, and that you can get yourself moving again when it isn't.

# %% [markdown]
# **Name:** **TJ Smith**
#
# **Assistant used (tool + model):** **Claude Code**

# %% [markdown]
# ---
# ## Problem 0: Environments and isolation [15 points]
#
# Read the chapter posted under Background Reading, up through but not including the `requirements.txt` section:
# https://jkropko.github.io/surfing-the-data-pipeline/docker.html
#
# Then follow the environment setup guide under "Creating and Connecting to the Conda Environment for this Class" in the "Getting Started with the Tools We'll Be Using" module on Canvas.

# %% [markdown]
# ### Part a [4 points]
#
# What are the primary uses of a virtual environment?
#
# **To isolate programming language versions and packages from the global system so that there are no contending dependencies and code will run on the correct versions of everything.**

# %% [markdown]
# ### Part b [5 points]
#
# Rank the global environment, a virtual environment, a container, and a virtual machine by how much they isolate. For each level, name one failure it fixes that the level below it does not.
#
# 1. **Virtual Machines:** VM's isolate both the entire operating system, programming version, and packages, but also the hardware of the system. This allows you to connect to a different computer housed in a server somewhere. This solves the proglems that containers do, but also allows you to work with big data and control your computers hardware properties. It is also completely isolated from the global environment.
# 2. **Containers:** Container's isolate the operating system, the packages, and the programming language used from the global environment. It also allows for the installation of applications outside of the programming language. This solves the problems that a virtual environment solves, but additionally allows you to write/run code that is reliant on differing operating systems.
# 3. **Virtual Environments:** Virtual environments isolate a folder with programming language and package versions from the global environment. This allows the user to use a different python or package version than what is installed in the global environment, which protects projects from breaking should the global versions be updated or changed.
# 4. **Global Environment:** The Global Environment is not isolated, and uses the programming language and package versions installed onto your computers operating system.

# %% [markdown]
# ### Part c [6 points]
#
# Create the course environment, select it as this notebook's kernel, then run the cell below. It should complete without error.

# %%
import sys
print(sys.version)
print(sys.executable)

import numpy as np
import pandas as pd
import plotly.express as px
import prince
import requests
import wquantiles
import matplotlib.pyplot as plt
import seaborn as sns
import sidetable
import sqlalchemy
import psycopg
import mysql.connector
import pymongo
from scipy import stats
from sklearn import manifold

# %%
sys.executable

# %% [markdown]
# Then answer, in one or two sentences: what does `sys.executable` print, and how would that output tell you that your notebook is running in the *wrong* environment?
#
# **It prints the path to the python language executable, which goes through your virtual environment. This would allow you to see if the executable is located in your venv or elsewhere.**

# %% [markdown]
# ---
# ## Problem 1: Reading tracebacks [20 points]
#
# The skill that matters is reading a traceback that has already happened and locating the line *in your own code* that caused it.
#
# For parts a–e: **run the cell, then report four things.** [4 points each]
#
# 1. The exception type
# 2. The last line in the traceback that belongs to *your* code, not to a library
# 3. A one-sentence diagnosis
# 4. A fix
#
# Each cell below is *supposed* to raise an error. Run them one at a time, because if you run all cells, execution will terminate at the first error.

# %% [markdown]
# ### Part a

# %%
import pandas as pd
df = pd.DataFrame({"city": ["Charlottesville", "Richmond"], "pop": [47000, 226000]})
df["population"]

# %% [markdown]
# **The exception type from the code above is "KeyError".**\
# **The last line of code from the original code is "df["population"]".**\
# **This code does not work because we are calling column "population" which does not exist in df, as the column we meant to call is called "pop".**\
# **We would fix this code by replacing "population" with "pop".**

# %% [markdown]
# ### Part b

# %%
import pandas as pd
df = pd.DataFrame({"n": ["1", "2", "three", "4"]})
df["n"].astype(int)

# %% [markdown]
# **The exception type from the code above is "ValueError".**\
# **The last line of code from the original code in the error is "df["n"].astype(int)".**\
# **The code above does not work because df column n contains a string, which cannot be cast to an integer.**\
# **The string "three" should be changed to "3".**

# %% [markdown]
# ### Part c

# %%
def normalize(values):
    total = sum(values)
    [v / total for v in values]

scaled = normalize([1, 2, 3])
print(len(scaled))

# %% [markdown]
# **The exception type from the code above is "TypeError".**\
# **The last line of code from the original code in the error is "print(len(scaled))".**\
# **The code above does not work because the normalize function does not return any value, and thus we have assigned no value, or "NoneType", to the variable "scaled", thus nothing can be printed.**\
# **The fix to this would be to add the word "return" before "[v / total for v in values]" so that it returns the resulting datatype.**

# %% [markdown]
# ### Part d

# %%
list = [3, 1, 2]
pairs = list(zip("abc", [1, 2, 3]))

# %% [markdown]
# **The exception type from the code above is "TypeError".**\
# **The last line of code from the original code in the error is "pairs = list(zip("abc",[1,2,3]))".**\
# **The reason this code does not work is because we have overwritten a builtin function with our variable, and then we attempt to call our variable as a function (hence "list object is not callable).**\
# **The solution to this is to rename our list to list1 or some other arbitrary name that does not overwrite a builtin function we plan to use.**

# %% [markdown]
# ### Part e

# %%
import math
big = 2 ** 10000
print(len(str(big)))   # this works

# %%
math.exp(10000)        # this does not

# %%
float(big)             # neither does this

# %% [markdown]
# **The exception types from these two lines of code are both "OverflowError".**\
# **There is only one line of code, and it appears in the error message.**\
# **The reason this code does not work is that we have attempted to either pass to these functions or evaluate these functions to a value greater than the system can handle.**\
# **The solution is to use smaller numbers.**

# %% [markdown]
# ---
# ## Problem 2: Getting answers from the code itself [12 points]
#
# Use docstrings, `help()`, or `?` in Jupyter. Do not use a search engine or an AI assistant for this problem — the skill being tested is finding the answer using help documentation, which is sometimes the fastest and most accurate way to solve a problem.

# %% [markdown]
# ### Part a [4 points]
#
# `pd.read_csv()` is slow on a large file. The docstring documents an `engine` parameter with more than one option. Which engine is the **default**? Which would you switch to for more speed, and what do you give up?

# %%
import pandas as pd
help(pd.read_csv)

# %% [markdown]
# **The default engine is None. I would switch to the pyarrow engine as it supports multithreading and is much faster, however you give up full functionality and some features are not supported.**

# %% [markdown]
# ### Part b [4 points]
#
# This semester we will discuss Python dictionaries, which store data in the following format:
# ```
# {'key':'value'}
# ```
# For example, here is a dictionary that stores notes about the places I've traveled to. The city names are the keys, and the notes are the values.

# %%
mytrips = {'Portland': 'So many bicycles',
           'Nashville': 'Lost in Opryland Mall again',
           'Richmond': 'Got tattoo and became a hipster',
           'San Diego': 'Chased off beach by sea lion'}

# %% [markdown]
# If I call a key directly using this syntax, I get it's value:

# %%
mytrips['Portland']

# %% [markdown]
# Using the help documentation, `help(mytrips)`, find a way to display all the cities without my travel notes.

# %%
help(mytrips)
mytrips.keys()

# %% [markdown]
# **mytrips.keys()**

# %% [markdown]
# ### Part c [4 points]
#
# You're using `px.scatter()` from Plotly Express. How would you add a box plot along the x-axis showing the distribution of the x variable?

# %%
import plotly.express as px
help(px.scatter)

# %% [markdown]
# **To do this you would need to call px.scatter(data_frame = df, marginal_x = 'box')**

# %% [markdown]
# ---
# ## Problem 3: The archive and its half-life [10 points]
#
# Stack Overflow accumulated the largest corpus of programming questions and answers ever assembled. It is also, as a place where people ask questions, effectively over: monthly question volume fell from roughly 207,000 in March 2014 to about 1,300 in July 2026.
#
# The decline started around 2014 — well before ChatGPT — when the site began closing duplicate and off-guideline questions more aggressively, and a great deal of the commentary on its collapse consists of people describing how badly they were treated when they tried to participate. Generative AI accelerated something that was already happening.
#
# You will almost certainly never post a question there. You will read it constantly, often without noticing, because it is a large part of what your AI assistant learned from.

# %% [markdown]
# The archive is still read heavily even though almost nobody adds to it. Given that, what happens to the quality of an assistant's answers about a library released — or substantially rewritten — *after* the archive stopped growing?

# %% [markdown]
# **Assistants' answers to questions, especially specific and detailed ones, about newer librarys or rewritten libraries will not be nearly as high quality and useful as their answers concerning older libraries where they have more information to pull from.**

# %% [markdown]
# ---
# ## Problem 4: The Avengers function [23 points]
#
# This problem walks you through using AI to help you debug code.
#
# Six superheroes count as original Avengers: Hulk, Captain America, Iron Man, Black Widow, Hawkeye, and Thor. Here is a function that is supposed to identify them.

# %%
def is_avenger(name):
    if name == "Hulk" or "Captain America" or "Iron Man" or "Black Widow" or "Hawkeye" or "Thor":
        print(name + "'s an original Avenger!")
    else:
        print(name + " is NOT an original Avenger.")

# %%
is_avenger("Black Widow")
is_avenger("Iron Man")
is_avenger("Spiderman")
is_avenger("Beyonce")

# %% [markdown]
# ### Part a [5 points]
#
# **Before running anything and before asking any assistant:** stare at the code and see if you can tell why this function returns the wrong answer for `"Beyonce"`. If you think you have an idea, write it down here. If you are stumped, spend at least 5 minutes thinking about it, then you can write here that you don't know. The point here is to engage your brain thinking about the code prior to turning to an AI.

# %% [markdown]
# **I don't know. Perhaps it is returning something other than True or False? Maybe it is just looking for the letters in Beyonce in the names?**

# %% [markdown]
# ### Part b [8 points]
#
# *Now* ask an AI assistant to fix the function. Paste your exact prompt and its exact response in the cells below. Then evaluate the response:
#
# - Did it explain *why* the original was broken, or did it just hand you working code?
# - Did it make a guess at your intentions by offering to expand the code?
# - Did it mention anything you had not already worked out in part a?
# - After having seen the AI's response, do you feel that you understand the mistake better?

# %% [markdown]
# **My prompt:** Why is this function: def is_avenger(name):
#     if name == "Hulk" or "Captain America" or "Iron Man" or "Black Widow" or "Hawkeye" or "Thor":
#         print(name + "'s an original Avenger!")
#     else:
#         print(name + " is NOT an original Avenger.") return True when I pass it Beyonce?
#
# **Its response:** The function prints "Beyonce's an original Avenger!" because of how Python evaluates the or condition.
#
# When you write:
#
#
# if name == "Hulk" or "Captain America" or "Iron Man" or ...
# Python evaluates it as:
#
#
# if (name == "Hulk") or ("Captain America") or ("Iron Man") or ...
# For name = "Beyonce":
#
# name == "Hulk" → False
# or "Captain America" → True (any non-empty string is truthy)
# Since the condition is True, the if-block executes
# The string "Captain America" isn't being compared to name—it's just being evaluated as a boolean, and it's truthy, so the entire condition is True regardless of what name is.
#
# Fix: Use in to check if name is in a list:
#
#
# def is_avenger(name):
#     if name in ["Hulk", "Captain America", "Iron Man", "Black Widow", "Hawkeye", "Thor"]:
#         print(name + "'s an original Avenger!")
#     else:
#         print(name + " is NOT an original Avenger.")
# Now it will correctly print "Beyonce is NOT an original Avenger."
#
# **My evaluation:**
# 1. It did explain why the original function was wrong, in addition to giving me better code.
# 2. It did not make a guess at my intentions by offering to expand the code.
# 3. Yes, everything it mentioned was something I did not know, and therefore was not part of part a.
# 4. After seeing this response, I understand my mistake significantly better, and I've learned something about the characteristics of strings as well as the or operator.

# %% [markdown]
# ### Part c [10 points]
#
# An old-school skill that is getting lost in the age of AI code assistants is the ability to craft a **minimal reproducible example**: small and as simple as possible, such that it is just sufficient to demonstrate the problem, but without any additional complexity or dependencies that will make resolution harder. Although it is easy to take the code as it is and dump it to the code assistant, a minimum reproducible example can help other people understand the bug, and can help AI solve the bug if the code is sufficiently complex (or at least can help the AI solve the problem at the cost of far fewer tokens).
#
# Write a **minimal reproducible example** of the Avengers bug — code you could paste to a colleague or into a prompt. It must:
#
# 1. Run on anyone's machine with no data file and no unusual packages
# 2. Reliably produce the wrong behavior
# 3. Use as few lines as possible
# 4. State the expected output and the actual output

# %%
# We expect the function to print "incorrect", but it prints "a" instead.
name = 'a'
if name == "b" or  "c":
    print(name)
else:
    print('incorrect')
# Out:
# a

# %% [markdown]
# ---
# ## Problem 5: Verifying code you did not write [20 points]
#
# This problem walks you through using AI to help you generate code that accomplishes a specific purpose.
#
# The Collatz Conjecture: take a positive integer; if it's even, divide by two; if it's odd, multiply by three and add one. Repeat. Every number tested so far eventually reaches the cycle 4, 2, 1. The conjecture is that this is true for all positive integers, but it remains unproven in general. (See https://xkcd.com/710/)

# %% [markdown]
# ### Part a [4 points]
#
# Ask your assistant for a Python function that applies the Collatz step **once** to a positive integer. Record your exact prompt and paste its exact output below.
#
# **My prompt:** Please write me a function that applies the Collatz step once to a positive integer.

# %%
# paste the assistant's function here
def collatz_step(n):
    if n % 2 == 0:
        return n // 2
    else:
        return 3 * n + 1

# %% [markdown]
# ### Part b [6 points]
#
# Now ask the assistant to add a `ValueError` if the input is negative and a `TypeError` if the input is not an integer. Paste what you get.

# %%
# paste the assistant's guarded function here, then audit it
def collatz_step(n):
    if not isinstance(n, int) or isinstance(n, bool): #Why is it necessary to check for the bool?
        raise TypeError("Input must be an integer")
    if n < 0: #This does not check for 0, which is not a positive integer.
        raise ValueError("Input must be a positive integer")
    
    if n % 2 == 0:
        return n // 2
    else:
        return 3 * n + 1

collatz_step(0)

# %% [markdown]
# ### Part c [5 points]
#
# Now ask the assistant to write a `while` loop that starts from a user-specified positive integer and applies your function until it reaches 1.
#
# Then answer: what happens if you feed it `0`? `-7`? `2.0`? Add a maximum-iteration guard and explain why an unproven conjecture is a good reason to have one.
# **If you pass the function 0, it will return a ValueError.**\
# **If you pass the function -7 it will return a ValueError.**\
# **If you pass the function 2.0, it will return a TypeError becuase 2.0 is a float, not an integer.**\
# **Having a maximum iteration guard is important with unproven conjectures because it is always possible that we may find a number that does not approach one, and thus the while loop will continue for infinity and may crash our computer and cause other problems in our code.**

# %%
# your loop here
def collatz_sequence(n):
    if not isinstance(n, int) or isinstance(n, bool):
        raise TypeError("Input must be an integer")
    if n <= 0:
        raise ValueError("Input must be a positive integer")
    
    steps = 0
    while n != 1:
        n = collatz_step(n)
        steps += 1
    if steps == 10000:
        raise RuntimeError("Exceeded maximum number of steps (10,000)")
    return steps

# %% [markdown]
# ### Part d [5 points]
#
# In a short paragraph, describe one thing your assistant got wrong in this problem, or one thing you had to change, and explain **how you noticed**.
#
# "It was correct and I changed nothing" receives no credit. If you found nothing, you did not test hard enough — go back to part b and try zero, try `True`, try a string.

# %% [markdown]
# **My assistant did not consider the case when it is passed 0 at first, however it corrected itself when I requested a more advanced function by adding "<=" rather than just <. My assistant was intelligent and also caught that it needed to check for bools, as they are treated as integers when passed to mathematical functions (1,0), so it added a check to see if the value passed was a boolean. I noticed these errors by thinking through the code line by line with the suggested inputs given in step c, where I noticed how important it was to think through all the possible input types that could be passed to the function.**
